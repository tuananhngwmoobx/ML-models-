# %%
import pandas as pd

# %%
# Set seed for reproducibility
np.random.seed(42)

# Generate synthetic data
city_population = np.random.randint(2_000_000, 30_000_000, size=100)

# Updated list of continents
continents = ['North America', 'South America', 'Asia', 'Europe']
continent = np.random.choice(continents, size=100)

venue_capacity = np.random.choice([8000, 11000, 12300, 15000, 14900, 22800, 33200], size=100)
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_of_week = np.random.choice(days_of_week, size=100)

multiple_concerts = np.random.choice([0, 1], size=100)
sold_out = np.random.choice([0, 1], size=100)

# Create the DataFrame
df = pd.DataFrame({
    'City Population': city_population,
    'Continent': continent,
    'Venue Capacity': venue_capacity,
    'Day of Week': day_of_week,
    'Multiple Concerts': multiple_concerts,
    'Sold Out': sold_out
})

# %%
df.head()
# Out:
#    City Population      Continent  Venue Capacity Day of Week  \
# 0         25200604         Europe           12300    Saturday
# 1         18094478  North America           12300      Friday
# 2         25327850  South America           22800   Wednesday
# 3         28858567           Asia           15000    Thursday
# 4         23081788  North America           11000    Thursday
#
#    Multiple Concerts  Sold Out
# 0                  1         1
# 1                  0         0
# 2                  1         0
# 3                  0         0
# 4                  1         1

# %%
df2 = pd.get_dummies(df[['Continent', 'Day of Week']])

# %%
df2
# Out:
#     Continent_Asia  Continent_Europe  Continent_North America  \
# 0            False              True                    False
# 1            False             False                     True
# 2            False             False                    False
# 3             True             False                    False
# 4            False             False                     True
# ..             ...               ...                      ...
# 95           False             False                     True
# 96           False              True                    False
# 97           False             False                     True
# 98           False              True                    False
# 99            True             False                    False
#
#     Continent_South America  Day of Week_Friday  Day of Week_Monday  \
# 0                     False               False               False
# 1                     False                True               False
# 2                      True               False               False
# 3                     False               False               False
# 4                     False               False               False
# ..                      ...                 ...                 ...
# 95                    False                True               False
# 96                    False               False               False
# 97                    False               False               False
# 98                    False               False               False
# 99                    False               False               False
#
#     Day of Week_Saturday  Day of Week_Sunday  Day of Week_Thursday  \
# 0                   True               False                 False
# 1                  False               False                 False
# 2                  False               False                 False
# 3                  False               False                  True
# 4                  False               False                  True
# ..                   ...                 ...                   ...
# 95                 False               False                 False
# 96                 False               False                 False
# 97                  True               False                 False
# 98                 False               False                 False
# 99                 False               False                 False
#
#     Day of Week_Tuesday  Day of Week_Wednesday
# 0                 False                  False
# 1                 False                  False
# 2                 False                   True
# 3                 False                  False
# 4                 False                  False
# ..                  ...                    ...
# 95                False                  False
# 96                False                   True
# 97                False                  False
# 98                False                   True
# 99                False                   True
#
# [100 rows x 11 columns]

# %%
df3 = pd.concat([df, df2], axis = 1)

# %%
df3
# Out:
#     City Population      Continent  Venue Capacity Day of Week  \
# 0          25200604         Europe           12300    Saturday
# 1          18094478  North America           12300      Friday
# 2          25327850  South America           22800   Wednesday
# 3          28858567           Asia           15000    Thursday
# 4          23081788  North America           11000    Thursday
# ..              ...            ...             ...         ...
# 95         24373627  North America           33200      Friday
# 96         28477560         Europe            8000   Wednesday
# 97          3007293  North America            8000    Saturday
# 98         23551399         Europe           15000   Wednesday
# 99          5366612           Asia           12300   Wednesday
#
#     Multiple Concerts  Sold Out  Continent_Asia  Continent_Europe  \
# 0                   1         1           False              True
# 1                   0         0           False             False
# 2                   1         0           False             False
# 3                   0         0            True             False
# 4                   1         1           False             False
# ..                ...       ...             ...               ...
# 95                  1         0           False             False
# 96                  1         0           False              True
# 97                  1         0           False             False
# 98                  1         1           False              True
# 99                  1         1            True             False
#
#     Continent_North America  Continent_South America  Day of Week_Friday  \
# 0                     False                    False               False
# 1                      True                    False                True
# 2                     False                     True               False
# 3                     False                    False               False
# 4                      True                    False               False
# ..                      ...                      ...                 ...
# 95                     True                    False                True
# 96                    False                    False               False
# 97                     True                    False               False
# 98                    False                    False               False
# 99                    False                    False               False
#
#     Day of Week_Monday  Day of Week_Saturday  Day of Week_Sunday  \
# 0                False                  True               False
# 1                False                 False               False
# 2                False                 False               False
# 3                False                 False               False
# 4                False                 False               False
# ..                 ...                   ...                 ...
# 95               False                 False               False
# 96               False                 False               False
# 97               False                  True               False
# 98               False                 False               False
# 99               False                 False               False
#
#     Day of Week_Thursday  Day of Week_Tuesday  Day of Week_Wednesday
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                   True
# 3                   True                False                  False
# 4                   True                False                  False
# ..                   ...                  ...                    ...
# 95                 False                False                  False
# 96                 False                False                   True
# 97                 False                False                  False
# 98                 False                False                   True
# 99                 False                False                   True
#
# [100 rows x 17 columns]

# %%
df4 = df3.drop(['Continent', 'Day of Week'], axis = 1)

# %%
df4
# Out:
#     City Population  Venue Capacity  Multiple Concerts  Sold Out  \
# 0          25200604           12300                  1         1
# 1          18094478           12300                  0         0
# 2          25327850           22800                  1         0
# 3          28858567           15000                  0         0
# 4          23081788           11000                  1         1
# ..              ...             ...                ...       ...
# 95         24373627           33200                  1         0
# 96         28477560            8000                  1         0
# 97          3007293            8000                  1         0
# 98         23551399           15000                  1         1
# 99          5366612           12300                  1         1
#
#     Continent_Asia  Continent_Europe  Continent_North America  \
# 0            False              True                    False
# 1            False             False                     True
# 2            False             False                    False
# 3             True             False                    False
# 4            False             False                     True
# ..             ...               ...                      ...
# 95           False             False                     True
# 96           False              True                    False
# 97           False             False                     True
# 98           False              True                    False
# 99            True             False                    False
#
#     Continent_South America  Day of Week_Friday  Day of Week_Monday  \
# 0                     False               False               False
# 1                     False                True               False
# 2                      True               False               False
# 3                     False               False               False
# 4                     False               False               False
# ..                      ...                 ...                 ...
# 95                    False                True               False
# 96                    False               False               False
# 97                    False               False               False
# 98                    False               False               False
# 99                    False               False               False
#
#     Day of Week_Saturday  Day of Week_Sunday  Day of Week_Thursday  \
# 0                   True               False                 False
# 1                  False               False                 False
# 2                  False               False                 False
# 3                  False               False                  True
# 4                  False               False                  True
# ..                   ...                 ...                   ...
# 95                 False               False                 False
# 96                 False               False                 False
# 97                  True               False                 False
# 98                 False               False                 False
# 99                 False               False                 False
#
#     Day of Week_Tuesday  Day of Week_Wednesday
# 0                 False                  False
# 1                 False                  False
# 2                 False                   True
# 3                 False                  False
# 4                 False                  False
# ..                  ...                    ...
# 95                False                  False
# 96                False                   True
# 97                False                  False
# 98                False                   True
# 99                False                   True
#
# [100 rows x 15 columns]

# %%
X = df4.drop(['Sold Out'], axis = 1)

# %%
y = df4['Sold Out']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.22      0.27         9
#            1       0.50      0.64      0.56        11
#
#     accuracy                           0.45        20
#    macro avg       0.42      0.43      0.41        20
# weighted avg       0.42      0.45      0.43        20

# %%
gnb.score(X_train, y_train)
# Out:
# 0.5

# %%
gnb.score(X_test, y_test)
# Out:
# 0.45

# %%
# add in parameter 
param_grid = {
    'var_smoothing': [0.00000001, 0.000000001, 0.00000001]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(gnb, param_grid, cv = 5, scoring = 'accuracy', n_jobs = -1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GaussianNB(), n_jobs=-1,
#              param_grid={'var_smoothing': [1e-08, 1e-09, 1e-08]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'var_smoothing': 1e-08}

# %%
grid_search.best_score_
# Out:
# np.float64(0.375)
